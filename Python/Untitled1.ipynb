# %%
# Imports
import math as m
import numpy as np
import matplotlib.pyplot as plt
import holoviews as hv
import pylab as pl
from pylab import exp,cos,sin,pi,tan, pi
import pandas as pd
import seaborn as sb
import holoviews as hv
from IPython.display import SVG
import io
from PIL import Image
from random import random
import elastica as el
import elastica_neurons as en
from dynamics import *
import matplotlib.pyplot as mpl
# %matplotlib inline
hv.notebook_extension()
# Out:
# /usr/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# <script type="text/javascript">
# function HoloViewsWidget(){
#         }
#
#         HoloViewsWidget.prototype.init_slider = function(init_val){
#             if(this.cached) {
#                 this.update_cache();
#                 this.update(0);
#             } else {
#                 this.dynamic_update(0);
#             }
#         }
#
#         HoloViewsWidget.prototype.populate_cache = function(idx){
#             if(this.load_json) {
#         		var data_url = "./" + this.id + '.json';
#         		$.getJSON(data_url, $.proxy(function(json_data) {
#         			this.frames = json_data;
#         			$.each(this.frames, $.proxy(function(index, frame) {
#         				this.cache[index].html(frame);
#         			}, this));
#         		}, this));
#             } else {
# ...

# %%
nosn = 3
orientations = np.arange(0, np.pi, np.pi/nosn)
x = np.arange(0,x_axis,x_axis/nosn)
c = vonMises(a,k,angle,orientations)
x
# Out:
# array([  0.        ,  10.66666667,  21.33333333])

# %%
# Different number of orientation
x_axis = 32.0
exp = 5
colors = mpl.cm.hsv((np.arange(0, 1, 1.0/exp)))
a = 1
k = 1
angle = np.pi/4
decoded_orientation = np.zeros(5)
mpl.rcParams.update({'font.size':16})
plt.rc('text', usetex=True)


nosn = 3
orientations = np.arange(0, np.pi, np.pi/nosn)
x = np.arange(0,x_axis,x_axis/nosn)
c = vonMises(a,k,angle,orientations)
plt1, = plt.plot(x,c,color=colors[0], label=nosn)
decoded_orientation[0] = popvec(c,nosn)

nosn = 5
orientations = np.arange(0, np.pi, np.pi/nosn)
x = np.arange(0,x_axis,x_axis/nosn)
c = vonMises(a,k,angle,orientations)
plt2, = plt.plot(x,c,color=colors[1], label=nosn)
decoded_orientation[1] = popvec(c,nosn)


nosn = 9
orientations = np.arange(0, np.pi, np.pi/nosn)
x = np.arange(0,x_axis,x_axis/nosn)
c = vonMises(a,k,angle,orientations)
plt3, = plt.plot(x,c,color=colors[2], label=nosn)
decoded_orientation[2] = popvec(c,nosn)

nosn = 16
orientations = np.arange(0, np.pi, np.pi/nosn)
x = np.arange(0,x_axis,x_axis/nosn)
c = vonMises(a,k,angle,orientations)
plt4, = plt.plot(x,c,color=colors[3], label=nosn)
decoded_orientation[3] = popvec(c,nosn)

nosn = 32
orientations = np.arange(0, np.pi, np.pi/nosn)
x = np.arange(0,x_axis,x_axis/nosn)
c = vonMises(a,k,angle,orientations)
plt5, = plt.plot(x,c,color=colors[4], label=nosn)
decoded_orientation[4] = popvec(c,nosn)

plt.legend(handles=[plt1,plt2,plt3,plt4,plt5])
plt.xlim([0,31])
plt.xticks([0,16,31],[0, 90, 180])
plt.yticks([0,1,2,3],[0,1,2,3])
#plt.ylim([-5.5,5.5])
plt.ylabel('Reponse')
plt.xlabel(r'Orientation Selective Neurons ($\phi_{i})$')
#plt.savefig('../Report/Pictures/experiments/basics/misesNumberNeurons2.png', dpi=200,bbox_inches='tight')

# %%
decoded_orientation*57.2958
# Out:
# array([ 90.00003218,  90.00003218, -90.00003218,  90.00003218,  90.00003218])

# %%
# Different number of orientation
nosn = 32.0
exp = 3
colors = mpl.cm.hsv((np.arange(0, 1, 1.0/exp)))
a = 1
k = 1
angle = np.pi/2
mpl.rcParams.update({'font.size':16})


a = 1
k = 0.5
nosn = 32
orientations = np.arange(0, np.pi, np.pi/nosn)
x = np.arange(0,x_axis,x_axis/nosn)
c = vonMises(a,k,angle,orientations)
plt1, = plt.plot(x,c,color=colors[0], label=k)
decoded_orientation[4] = popvec(c,nosn)

a = 1
k = 1
nosn = 32
orientations = np.arange(0, np.pi, np.pi/nosn)
x = np.arange(0,x_axis,x_axis/nosn)
c = vonMises(a,k,angle,orientations)
plt2, = plt.plot(x,c,color=colors[1], label=k)
decoded_orientation[4] = popvec(c,nosn)


a = 1
k = 2
nosn = 32
orientations = np.arange(0, np.pi, np.pi/nosn)
x = np.arange(0,x_axis,x_axis/nosn)
c = vonMises(a,k,angle,orientations)
plt3, = plt.plot(x,c,color=colors[2], label=k)
decoded_orientation[4] = popvec(c,nosn)

plt.legend(handles=[plt1,plt2,plt3])
plt.xlim([0,31])
plt.xticks([0,16,31],[0, 90, 180])
#plt.yticks([0,1,2,3],[0,1,2,3])
#plt.ylim([-5.5,5.5])
plt.ylabel('Reponse')
plt.xlabel(r'Presented orientation ($\theta_{c})$')
plt.savefig('../Report/Pictures/experiments/basics/misesNumberA.png', dpi=200,bbox_inches='tight')

# %%
# Different number of orientation
nosn = 32.0
exp = 3
colors = mpl.cm.hsv((np.arange(0, 1, 1.0/exp)))
a = 1
k = 1
angle = np.pi/2
mpl.rcParams.update({'font.size':16})


a = 1
k = 1
nosn = 32
orientations = np.arange(0, np.pi, np.pi/nosn)
x = np.arange(0,x_axis,x_axis/nosn)
c = vonMises(a,k,angle,orientations)
plt1, = plt.plot(x,c,color=colors[0], label=a)
decoded_orientation[4] = popvec(c,nosn)

a = 0.5
k = 1
nosn = 32
orientations = np.arange(0, np.pi, np.pi/nosn)
x = np.arange(0,x_axis,x_axis/nosn)
c = vonMises(a,k,angle,orientations)
plt2, = plt.plot(x,c,color=colors[1], label=a)
decoded_orientation[4] = popvec(c,nosn)


a = 2
k = 1
nosn = 32
orientations = np.arange(0, np.pi, np.pi/nosn)
x = np.arange(0,x_axis,x_axis/nosn)
c = vonMises(a,k,angle,orientations)
plt3, = plt.plot(x,c,color=colors[2], label=a)
decoded_orientation[4] = popvec(c,nosn)

plt.legend(handles=[plt1,plt2,plt3])
plt.xlim([0,31])
plt.xticks([0,16,31],[0, 90, 180])
#plt.yticks([0,1,2,3],[0,1,2,3])
#plt.ylim([-5.5,5.5])
plt.ylabel('Reponse')
plt.xlabel(r'Presented orientation ($\theta_{c})$')
plt.savefig('../Report/Pictures/experiments/basics/misesNumberB.png', dpi=200,bbox_inches='tight')

# %%
# Different number of orientation
x_axis = 32.0
exp = 5
colors = mpl.cm.hsv((np.arange(0, 1, 1.0/exp)))
a = 3
k = 0.25
angle = np.pi/2
decoded_orientation = np.zeros(5)
mpl.rcParams.update({'font.size':16})

nosn = 32
orientations = np.arange(0, np.pi, np.pi/nosn)
x = np.arange(0,x_axis,x_axis/nosn)
c = vonMises(a,k,angle,orientations)
plt1, = plt.plot(x,c,color=colors[0], label=nosn)
decoded_orientation[0] = popvec(c,nosn)

plt.xlim([0,31])
plt.xticks([0,16,31],[0, 90, 180])
plt.yticks([0,1,2,3],[0,1,2,3])
#plt.ylim([-5.5,5.5])
plt.ylabel('Reponse')
plt.xlabel(r"Presented orientation ($\theta_{c}$)")
#plt.savefig('../Report/Pictures/experiments/basics/simpleMises.png', dpi=200,bbox_inches='tight')
